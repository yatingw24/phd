# %%
import pandas as pd

# Define the URL
url = "https://www.phdstipends.com/csv"

# Read the CSV file into a DataFrame
df = pd.read_csv(url)

# Save it locally as a CSV file
df.to_csv("phd_stipends.csv", index=False)

# Display the first few rows
df
# Out:
#                                            University              Department  \
# 0                                     Rice University         Applied Physics
# 1                 University of California - Berkeley               Chemistry
# 2      Georgia Institute of Technology (Georgia Tech)               Chemistry
# 3                        Sam Houston State University              Education
# 4                     Case Western Reserve University  Biomedical Engineering
# ...                                               ...                     ...
# 16969                            Duke University (DU)            Biochemistry
# 16970                    University of Virginia (UVA)    Chemical Engineering
# 16971                            Duke University (DU)  Biomedical Engineering
# 16972                    University of Virginia (UVA)    Chemical Engineering
# 16973                            Duke University (DU)  Biomedical Engineering
#
#       Overall Pay  LW Ratio Academic Year Program Year 12 M Gross Pay  \
# 0          $2,663      0.12     2025-2026          1st         $3,333
# 1         $47,000      1.69     2025-2026          1st        $47,000
# 2         $35,408      1.52     2025-2026          1st        $37,500
# 3         $30,000      1.49     2025-2026          1st        $30,000
# 4         $39,834      1.99     2024-2025          2nd        $40,000
# ...           ...       ...           ...          ...            ...
# 16969     $29,840      1.59     2012-2013   6th and up        $29,840
# 16970     $32,000      1.63     2013-2014          4th        $32,000
# 16971     $32,000      1.70     2013-2014          2nd        $32,000
# 16972     $25,000      1.28     2013-2014          4th        $25,000
# 16973     $27,850      1.48     2013-2014   6th and up        $27,850
#
#       9 M Gross Pay 3 M Gross Pay    Fees  \
# 0               NaN           NaN    $670
# 1               NaN           NaN     NaN
# 2               NaN           NaN  $2,092
# 3               NaN           NaN     NaN
# 4               NaN           NaN    $166
# ...             ...           ...     ...
# 16969           NaN           NaN     NaN
# 16970           NaN           NaN     NaN
# 16971           NaN           NaN     NaN
# 16972           NaN           NaN     NaN
# 16973           NaN           NaN     NaN
#
#                                                 Comments
# 0      Full funding, there is no tuition fee. The sti...
# 1                                                    NaN
# 2                           Health insurance is 779/year
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 16969                                                NaN
# 16970  This includes health insurance coverage, tuiti...
# 16971  This is the stipend associated with the NSF Fe...
# 16972  This stipend includes full health insurance co...
# 16973  I just receive the base stipend in my departme...
#
# [16974 rows x 11 columns]

# %%
df_recent = df[(df['Academic Year'] == '2023-2024') | (df['Academic Year'] == '2024-2025') | (df['Academic Year'] == '2022-2023')]

# %%
df_recent[df_recent['Department'] == 'Physics'].head(40)
# Out:
#                                         University Department Overall Pay  \
# 159                     University of Chicago (UC)    Physics     $45,000
# 205     University of Minnesota - Twin Cities (UM)    Physics     $28,000
# 252                              Boston University    Physics     $40,000
# 375           University of Mississippi (Ole Miss)    Physics     $19,780
# 380        University of California - Irvine (UCI)    Physics     $38,000
# 432       University of Alabama - Huntsville (UAH)    Physics     $19,500
# 434         North Carolina State University (NCSU)    Physics     $34,180
# 545                            Brandeis University    Physics     $38,000
# 546              University of Geneva, Switzerland    Physics     $57,435
# 718                            Boston College (BC)    Physics     $33,000
# 777            University of California - Berkeley    Physics     $46,000
# 789                        Clemson University (CU)    Physics     $27,000
# 819                         Temple University (TU)    Physics     $32,033
# 882    Washington University in St. Louis (Wash U)    Physics     $40,000
# 966                    University of Kentucky (UK)    Physics     $24,000
# 1093                        Boston University (BU)    Physics     $41,000
# 1114                University of Arizona (U of A)    Physics     $26,000
# 1137               Case Western Reserve University    Physics     $37,000
# 1173                             Dartmouth College    Physics     $40,000
# 1260                       Cornell University (CU)    Physics     $44,080
# 1329  California Institute of Technology (Caltech)    Physics     $-1,000
# 1402                   Ohio State University (OSU)    Physics     $36,000
# 1442                University of Arizona (U of A)    Physics     $20,850
# 1521             Kansas State University (K-State)    Physics     $21,000
# 1652                           Brandeis University    Physics     $37,500
# 1729                    University of Florida (UF)    Physics     $23,600
# 1744   Massachusetts Institute of Technology (MIT)    Physics     $46,900
# 1779                      Stanford University (SU)    Physics     $51,108
# 1794                   University of Oklahoma (OU)    Physics     $24,000
# 1814             University of South Florida (UCF)    Physics     $21,800
# 1858               Case Western Reserve University    Physics     $27,920
# 1859               Case Western Reserve University    Physics     $27,920
# 1891             University of Texas - Austin (UT)    Physics     $32,000
# 1957           University of California - Berkeley    Physics     $44,958
# 1972                           Boston College (BC)    Physics     $34,000
# 2027                 University of Washington (UW)    Physics     $34,000
# 2040                          Duke University (DU)    Physics     $38,600
# 2068    CUNY Graduate School and University Center    Physics     $31,000
# 2116                         Georgetown University    Physics     $34,492
# 2127                Arizona State University (ASU)    Physics     $23,000
#
#       LW Ratio Academic Year Program Year 12 M Gross Pay 9 M Gross Pay  \
# 159       1.85     2024-2025   6th and up        $45,000           NaN
# 205       1.22     2022-2023          1st        $30,200           NaN
# 252        NaN     2023-2024          1st        $40,000           NaN
# 375       0.91     2023-2024          1st            NaN       $18,000
# 380       1.30     2024-2025          2nd        $38,000           NaN
# 432       0.92     2022-2023          1st            NaN       $16,000
# 434       1.50     2024-2025          NaN        $35,000           NaN
# 545       1.36     2024-2025          1st        $38,000           NaN
# 546        NaN     2024-2025          1st        $57,500           NaN
# 718       1.18     2023-2024          NaN        $33,000           NaN
# 777       1.66     2022-2023          NaN        $46,000           NaN
# 789       1.30     2022-2023          NaN            NaN       $27,000
# 819       1.33     2023-2024          1st        $33,333           NaN
# 882       1.93     2024-2025          1st        $40,000           NaN
# 966       1.18     2024-2025          1st            NaN       $24,000
# 1093      1.43     2024-2025          1st        $41,000           NaN
# 1114      1.25     2022-2023          1st            NaN       $26,000
# 1137      1.85     2023-2024          5th        $37,000           NaN
# 1173      1.61     2023-2024          NaN        $40,000           NaN
# 1260      1.82     2022-2023          5th        $44,080           NaN
# 1329     -0.04     2022-2023          1st         $6,000           NaN
# 1402      1.79     2022-2023          1st        $36,000           NaN
# 1442      1.01     2022-2023          1st            NaN       $21,750
# 1521      0.95     2022-2023          2nd        $21,000           NaN
# 1652      1.34     2022-2023          1st        $37,500           NaN
# 1729      1.04     2022-2023          2nd        $25,000           NaN
# 1744      1.68     2022-2023          1st        $46,900           NaN
# 1779      1.78     2023-2024          1st        $51,108           NaN
# 1794      1.19     2022-2023          5th        $24,000           NaN
# 1814      0.99     2022-2023          1st        $24,000           NaN
# 1858      1.40     2022-2023          3rd        $28,000           NaN
# 1859      1.40     2022-2023          3rd        $28,000           NaN
# 1891      1.40     2022-2023          4th        $32,000           NaN
# 1957      1.62     2023-2024          1st            NaN       $44,958
# 1972      1.22     2023-2024          1st        $34,000           NaN
# 2027      1.46     2022-2023          2nd        $35,000           NaN
# 2040      1.74     2023-2024          1st        $38,600           NaN
# 2068      1.04     2022-2023          1st        $31,000           NaN
# 2116      1.12     2023-2024          1st            NaN       $34,492
# 2127      1.04     2023-2024          1st        $24,000           NaN
#
#      3 M Gross Pay    Fees                                           Comments
# 159            NaN     NaN                                                NaN
# 205            NaN  $2,200  My fees are a bit more than average at UMN bec...
# 252            NaN     NaN  Post-taxes, this comes to a monthly stipend of...
# 375         $2,000    $220                                                NaN
# 380            NaN     NaN                                                NaN
# 432         $4,000    $500  More fees (optional and mandatory) have been a...
# 434            NaN    $820                                                NaN
# 545            NaN     NaN                                                NaN
# 546            NaN     $65  This salary is paid by the Department of Quant...
# 718            NaN     NaN                                                NaN
# 777            NaN     NaN                                                NaN
# 789            NaN     NaN  Paid $27,000 for 9 months. Have to pay semeste...
# 819            NaN  $1,300  Tax cuts are 451 per month. 80 is state and ci...
# 882            NaN     NaN                                                NaN
# 966            NaN     NaN                                                NaN
# 1093           NaN     NaN                                                NaN
# 1114           NaN     NaN                                                NaN
# 1137           NaN     NaN                                                NaN
# 1173           NaN     NaN                                                NaN
# 1260           NaN     NaN                                                NaN
# 1329           NaN  $7,000                                                NaN
# 1402           NaN     NaN                                                NaN
# 1442           NaN    $900                                                NaN
# 1521           NaN     NaN  Graduate Research Assistant, the group/mentor ...
# 1652           NaN     NaN                                                NaN
# 1729           NaN  $1,400                                                NaN
# 1744           NaN     NaN                                                NaN
# 1779           NaN     NaN                                                NaN
# 1794           NaN     NaN                                                NaN
# 1814           NaN  $2,200  All PhDs at USF needs to pay an additional of ...
# 1858           NaN     $80                                                NaN
# 1859           NaN     $80                                                NaN
# 1891           NaN     NaN                                                NaN
# 1957           NaN     NaN                                                NaN
# 1972           NaN     NaN                                                NaN
# 2027           NaN  $1,000                                                NaN
# 2040           NaN     NaN                                                NaN
# 2068           NaN     NaN                                                NaN
# 2116           NaN     NaN                                                NaN
# 2127           NaN  $1,000  seems low , more than 1/2 your pay will go to ...

# %%
df_recent = df_recent.dropna(subset=['Department'])
df_recent['Overall Pay'] = df_recent['Overall Pay'].astype(str).str.replace('[$,]', '', regex=True).astype(float)

# %%
df_recent['Overall Pay'] = pd.to_numeric(df_recent['Overall Pay'], errors='coerce')

# Drop rows where "Overall Pay" is negative or NaN
df_recent = df_recent[df_recent['Overall Pay'] >= 0]
